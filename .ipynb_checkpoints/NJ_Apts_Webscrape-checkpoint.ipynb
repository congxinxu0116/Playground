# %% [markdown]
# # Web Scraping for Apartment Details in Jersey City, NJ
#
# ## List of Apartments:
# 1. [70 Greene Apartments](https://www.equityapartments.com/new-york-city/jersey-city/70-greene-apartments)
# 2. [Hudson Point](https://www.equityapartments.com/new-york-city/jersey-city/hudson-point-apartments)
# 3. [The Pier](https://www.equityapartments.com/new-york-city/jersey-city/the-pier-apartments)
# 4. [Windsor at Liberty House](https://www.windsoratlibertyhouse.com/)
# 5. [Vine](https://vinehoboken.com/)

# %% [markdown]
# ### [70 Greene Apartments](https://www.equityapartments.com/new-york-city/jersey-city/70-greene-apartments)

# %%
# Webscraping the Apartment Price in Jersey City
# Congxin (David) Xu
# 12/14/2020

# %% Import Modules
import pandas
import requests
from bs4 import BeautifulSoup
# %% Define parameters
# Store the URL as a variable
url = 'https://www.equityapartments.com/new-york-city/jersey-city/70-greene-apartments'

# Create a headers with user agent string
headers = {'user-agent': 'David Xu Personal Use (cx2rx@virginia.edu)'}

# Get the URL page
r = requests.get(url, headers = headers)

# Check status
print(r)
# Out:
# <Response [200]>

# %%
# Parse the HTML with Beautiful Soup
apts = BeautifulSoup(r.text, 'html.parser')

# Create empty list to store results
model = list()
available = list()
price = list()
time_period = list()
area = list()
floor = list()
amenity = list()
image = list()

# Iterate over all available apartments
for i in range(0, len(apts.find_all("ea5-unit"))):
    model += [apts.find_all("ea5-unit")[i].find_all('p')[1].get_text().strip()]
    available += [apts.find_all('ea5-unit')[i].find_all('p')[3].get_text().strip().split(" ")[1]]
    price += [apts.find_all("ea5-unit")[i].find_all("span")[0].get_text().split('$')[1]]
    time_period += [apts.find_all("ea5-unit")[i].find_all("span")[1].get_text()]
    area += [apts.find_all("ea5-unit")[i].find_all("span")[2].get_text().split(" ")[0]]
    image += [apts.find_all("ea5-unit")[i].find('img')['src']]
    
    # Handling Missing floor...
    try:
        apts.find_all("ea5-unit")[i].find_all("span")[3].get_text().split(" ")[1]
    except:
        floor += ['NA']
    else: 
        floor += [apts.find_all("ea5-unit")[i].find_all("span")[3].get_text().split(" ")[1]]
    
    # Hanlding multiple amenities...
    tmp = list()
    for j in range(0, len(apts.find_all("ea5-unit")[i].find_all('p', class_= 'amenity'))):
        tmp += [apts.find_all("ea5-unit")[i].find_all('p', class_= 'amenity')[j].get_text().strip()]
    amenity += [tmp]
    
# Create a data frame for return
d = {'model': model, 'price': price, 'available': available, 'time_period': time_period, 
     'area': area, 'floor': floor, 'amenity': amenity, 'image': image}
df = pandas.DataFrame(data=d)
df
# Out:
#              model  price   available time_period  area floor  \
# 0   0 Bed / 1 Bath  1,872   1/27/2021       12 mo   505    17
# 1   0 Bed / 1 Bath  1,888   2/13/2021       12 mo   505    20
# 2   0 Bed / 1 Bath  2,027   2/20/2021       12 mo   505    35
# 3   0 Bed / 1 Bath  2,052  12/17/2020       12 mo   505    35
# 4   0 Bed / 1 Bath  2,073    2/9/2021       12 mo   505    NA
# 5   0 Bed / 1 Bath  2,094    2/2/2021       12 mo   505    46
# 6   0 Bed / 1 Bath  2,146   2/26/2021       12 mo   627    30
# 7   0 Bed / 1 Bath  2,177    1/6/2021       12 mo   627    27
# 8   0 Bed / 1 Bath  2,229  12/17/2020       12 mo   627    38
# 9   0 Bed / 1 Bath  2,250   1/15/2021       12 mo   627    43
# 10  1 Bed / 1 Bath  2,112  12/17/2020       12 mo   592    19
# 11  1 Bed / 1 Bath  2,219    1/1/2021       12 mo   592    22
# 12  1 Bed / 1 Bath  2,225    1/6/2021       12 mo   592    26
# 13  1 Bed / 1 Bath  2,230  12/17/2020       12 mo   755     8
# 14  1 Bed / 1 Bath  2,250   2/12/2021       12 mo   755     7
# 15  1 Bed / 1 Bath  2,301   2/27/2021       12 mo   756    17
# 16  1 Bed / 1 Bath  2,323  12/17/2020       12 mo   858     6
# 17  1 Bed / 1 Bath  2,430  12/23/2020       12 mo   736    38
# 18  1 Bed / 1 Bath  2,492   1/30/2021       12 mo   839    15
# 19  1 Bed / 1 Bath  2,513  12/17/2020       12 mo   756    23
# 20  1 Bed / 1 Bath  2,534   2/17/2021       12 mo   665    38
# 21  1 Bed / 1 Bath  2,538    2/5/2021       12 mo   756    24
# 22  1 Bed / 1 Bath  2,544    1/9/2021       12 mo   839    27
# 23  1 Bed / 1 Bath  2,559  12/17/2020       12 mo   736    35
# 24  1 Bed / 1 Bath  2,570   2/12/2021       12 mo   803    27
# 25  1 Bed / 1 Bath  2,601    1/8/2021       12 mo   694    44
# 26  1 Bed / 1 Bath  2,622   1/16/2021       12 mo   839    19
# 27  1 Bed / 1 Bath  2,646   1/15/2021       12 mo   839    18
# 28  1 Bed / 1 Bath  2,673   1/29/2021       12 mo   712    44
# 29  1 Bed / 1 Bath  2,835  12/17/2020       12 mo   741    47
# 30  1 Bed / 1 Bath  2,899    1/8/2021       12 mo  1039     3
# 31  1 Bed / 1 Bath  2,905   1/12/2021       12 mo   764    48
# 32  1 Bed / 1 Bath  2,925  12/17/2020       12 mo  1083     8
# 33  1 Bed / 1 Bath  2,930  12/21/2020       12 mo  1083     9
# 34  1 Bed / 1 Bath  3,110  12/17/2020       12 mo  1267     4
# 35  2 Bed / 2 Bath  3,538    1/7/2021       12 mo  1014    29
# 36  2 Bed / 2 Bath  3,601  12/17/2020       12 mo  1014    30
# 37  2 Bed / 2 Bath  3,816    2/6/2021       12 mo  1014    NA
# 38  2 Bed / 2 Bath  4,075  12/17/2020       12 mo  1005    47
# 39  2 Bed / 2 Bath  4,281  12/17/2020       12 mo  1133    47
# 40  3 Bed / 2 Bath  4,062  12/17/2020       12 mo  1313    12
# 41  3 Bed / 2 Bath  4,494  12/17/2020       12 mo  1313    22
#
#                                               amenity  \
# 0                                  [Western Exposure]
# 1                                  [Western Exposure]
# 2                 [Hardwood Floors, Western Exposure]
# 3   [Hardwood Floors, Kitchen Backsplash, Western ...
# 4                 [Hardwood Floors, Western Exposure]
# 5                 [Hardwood Floors, Western Exposure]
# 6                                  [Western Exposure]
# 7                 [Hardwood Floors, Western Exposure]
# 8                 [Hardwood Floors, Western Exposure]
# 9                 [Hardwood Floors, Western Exposure]
# 10                                 [Western Exposure]
# 11  [Eastern Exposure, Kitchen Backsplash, Norther...
# 12              [Eastern Exposure, Northern Exposure]
# 13  [Exterior Brick Facade, Southern Exposure, Wes...
# 14          [Exterior Brick Facade, Western Exposure]
# 15                                [Southern Exposure]
# 16          [Exterior Brick Facade, Western Exposure]
# 17  [Eastern Exposure, Hardwood Floors, Kitchen Ba...
# 18             [Kitchen Backsplash, Western Exposure]
# 19                                [Northern Exposure]
# 20  [Eastern Exposure, Hardwood Floors, Southern E...
# 21                                 [Western Exposure]
# 22             [Kitchen Backsplash, Western Exposure]
# 23  [Hardwood Floors, Kitchen Backsplash, Southern...
# 24              [Northern Exposure, Western Exposure]
# 25  [Hardwood Floors, Kitchen Backsplash, View of ...
# 26      [Kitchen Backsplash, View of Lower Manhattan]
# 27                       [Balcony, Northern Exposure]
# 28  [Hardwood Floors, Kitchen Backsplash, View of ...
# 29                         [Balcony, Hardwood Floors]
# 30  [2 Floors of Living Space, Exterior Brick Faca...
# 31  [Hardwood Floors, Southern Exposure, View of M...
# 32        [Exterior Brick Facade, Kitchen Backsplash]
# 33        [Exterior Brick Facade, Kitchen Backsplash]
# 34  [Exterior Brick Facade, Kitchen Backsplash, Vi...
# 35             [Eastern Exposure, Kitchen Backsplash]
# 36             [Eastern Exposure, Kitchen Backsplash]
# 37  [Hardwood Floors, View of Mountains and Jersey...
# 38  [Eastern Exposure, Hardwood Floors, Kitchen Ba...
# 39  [Hardwood Floors, Kitchen Backsplash, View of ...
# 40             [Kitchen Backsplash, Western Exposure]
# 41              [Eastern Exposure, Northern Exposure]
#
#                                                 image
# 0   https://media.equityapartments.com/image/uploa...
# 1   https://media.equityapartments.com/image/uploa...
# 2   https://media.equityapartments.com/image/uploa...
# 3   https://media.equityapartments.com/image/uploa...
# 4   https://media.equityapartments.com/image/uploa...
# 5   https://media.equityapartments.com/image/uploa...
# 6   https://media.equityapartments.com/image/uploa...
# 7   https://media.equityapartments.com/image/uploa...
# 8   https://media.equityapartments.com/image/uploa...
# 9   https://media.equityapartments.com/image/uploa...
# 10  https://media.equityapartments.com/image/uploa...
# 11  https://media.equityapartments.com/image/uploa...
# 12  https://media.equityapartments.com/image/uploa...
# 13  https://media.equityapartments.com/image/uploa...
# 14  https://media.equityapartments.com/image/uploa...
# 15  https://media.equityapartments.com/image/uploa...
# 16  https://media.equityapartments.com/image/uploa...
# 17  https://media.equityapartments.com/image/uploa...
# 18  https://media.equityapartments.com/image/uploa...
# 19  https://media.equityapartments.com/image/uploa...
# 20  https://media.equityapartments.com/image/uploa...
# 21  https://media.equityapartments.com/image/uploa...
# 22  https://media.equityapartments.com/image/uploa...
# 23  https://media.equityapartments.com/image/uploa...
# 24  https://media.equityapartments.com/image/uploa...
# 25  https://media.equityapartments.com/image/uploa...
# 26  https://media.equityapartments.com/image/uploa...
# 27  https://media.equityapartments.com/image/uploa...
# 28  https://media.equityapartments.com/image/uploa...
# 29  https://media.equityapartments.com/image/uploa...
# 30  https://media.equityapartments.com/image/uploa...
# 31  https://media.equityapartments.com/image/uploa...
# 32  https://media.equityapartments.com/image/uploa...
# 33  https://media.equityapartments.com/image/uploa...
# 34  https://media.equityapartments.com/image/uploa...
# 35  https://media.equityapartments.com/image/uploa...
# 36  https://media.equityapartments.com/image/uploa...
# 37  https://media.equityapartments.com/image/uploa...
# 38  https://media.equityapartments.com/image/uploa...
# 39  https://media.equityapartments.com/image/uploa...
# 40  https://media.equityapartments.com/image/uploa...
# 41  https://media.equityapartments.com/image/uploa...

# %%
df.to_csv('70_greene_apartments_availability.csv')

# %% [markdown]
# ### [Hudson Point](https://www.equityapartments.com/new-york-city/jersey-city/hudson-point-apartments)

# %%
# Store the URL as a variable
url = 'https://www.equityapartments.com/new-york-city/jersey-city/hudson-point-apartments'

# Create a headers with user agent string
headers = {'user-agent': 'David Xu Personal Use (cx2rx@virginia.edu)'}

# Get the URL page
r = requests.get(url, headers = headers)

# Check status
print(r)
# Out:
# <Response [200]>

# %%
# Parse the HTML with Beautiful Soup
apts = BeautifulSoup(r.text, 'html.parser')

# Create empty list to store results
model = list()
available = list()
price = list()
time_period = list()
area = list()
floor = list()
amenity = list()
image = list()

# Iterate over all available apartments
for i in range(0, len(apts.find_all("ea5-unit"))):
    model += [apts.find_all("ea5-unit")[i].find_all('p')[1].get_text().strip()]
    available += [apts.find_all('ea5-unit')[i].find_all('p')[3].get_text().strip().split(" ")[1]]
    price += [apts.find_all("ea5-unit")[i].find_all("span")[0].get_text().split('$')[1]]
    time_period += [apts.find_all("ea5-unit")[i].find_all("span")[1].get_text()]
    area += [apts.find_all("ea5-unit")[i].find_all("span")[2].get_text().split(" ")[0]]
    image += [apts.find_all("ea5-unit")[i].find('img')['src']]
    
    # Handling Missing floor...
    try:
        apts.find_all("ea5-unit")[i].find_all("span")[3].get_text().split(" ")[1]
    except:
        floor += ['NA']
    else: 
        floor += [apts.find_all("ea5-unit")[i].find_all("span")[3].get_text().split(" ")[1]]
    
    # Hanlding multiple amenities...
    tmp = list()
    for j in range(0, len(apts.find_all("ea5-unit")[i].find_all('p', class_= 'amenity'))):
        tmp += [apts.find_all("ea5-unit")[i].find_all('p', class_= 'amenity')[j].get_text().strip()]
    amenity += [tmp]
    
# Create a data frame for return
d = {'model': model, 'price': price, 'available': available, 'time_period': time_period, 
     'area': area, 'floor': floor, 'amenity': amenity, 'image': image}
df = pandas.DataFrame(data=d)
df
# Out:
#              model  price   available time_period  area floor  \
# 0   1 Bed / 1 Bath  2,106  12/17/2020       12 mo   726     6
# 1   1 Bed / 1 Bath  2,129    1/9/2021       12 mo   726     3
# 2   1 Bed / 1 Bath  2,149   1/13/2021       12 mo   726     4
# 3   1 Bed / 1 Bath  2,203  12/17/2020       12 mo   726     6
# 4   1 Bed / 1 Bath  2,208  12/24/2020       12 mo   726     5
# 5   1 Bed / 1 Bath  2,398   1/29/2021       12 mo   726     6
# 6   1 Bed / 1 Bath  2,481    1/5/2021       12 mo   824     6
# 7   1 Bed / 1 Bath  2,496    2/4/2021       12 mo   824     4
# 8   1 Bed / 1 Bath  2,593    2/4/2021       12 mo   931    NA
# 9   2 Bed / 2 Bath  2,946  12/17/2020       12 mo  1213    NA
# 10  2 Bed / 2 Bath  3,175   2/19/2021       12 mo  1109     4
# 11  2 Bed / 2 Bath  3,228    2/4/2021       12 mo  1113     6
#
#                                               amenity  \
# 0   [Bay Window, Hardwood Floors, Modern Kitchen F...
# 1               [Bay Window, Modern Kitchen Features]
# 2   [Bay Window, Marble Tile, Modern Kitchen Featu...
# 3   [Bay Window, Hardwood Floors, Marble Tile, Mod...
# 4   [Bay Window, Hardwood Floors, Modern Kitchen F...
# 5   [Bay Window, Hardwood Floors, Modern Kitchen F...
# 6   [Hardwood Floors, Marina and Statue of Liberty...
# 7   [Hardwood Floors, Kitchen Window, Marina and S...
# 8           [Kitchen Window, Modern Kitchen Features]
# 9   [Corner Unit, Kitchen Window, Modern Kitchen F...
# 10   [Large Private Terrace, Modern Kitchen Features]
# 11  [Bay Window, Corner Unit, Modern Kitchen Featu...
#
#                                                 image
# 0   https://media.equityapartments.com/image/uploa...
# 1   https://media.equityapartments.com/image/uploa...
# 2   https://media.equityapartments.com/image/uploa...
# 3   https://media.equityapartments.com/image/uploa...
# 4   https://media.equityapartments.com/image/uploa...
# 5   https://media.equityapartments.com/image/uploa...
# 6   https://media.equityapartments.com/image/uploa...
# 7   https://media.equityapartments.com/image/uploa...
# 8   https://media.equityapartments.com/image/uploa...
# 9   https://media.equityapartments.com/image/uploa...
# 10  https://media.equityapartments.com/image/uploa...
# 11  https://media.equityapartments.com/image/uploa...

# %%
df.to_csv('Hudson_Point_availability.csv')

# %% [markdown]
# ### [The Pier](https://www.equityapartments.com/new-york-city/jersey-city/the-pier-apartments)

# %%
# Store the URL as a variable
url = 'https://www.equityapartments.com/new-york-city/jersey-city/the-pier-apartments'

# Create a headers with user agent string
headers = {'user-agent': 'David Xu Personal Use (cx2rx@virginia.edu)'}

# Get the URL page
r = requests.get(url, headers = headers)

# Check status
print(r)
# Out:
# <Response [200]>

# %%
# Parse the HTML with Beautiful Soup
apts = BeautifulSoup(r.text, 'html.parser')

# Create empty list to store results
model = list()
available = list()
price = list()
time_period = list()
area = list()
floor = list()
amenity = list()
image = list()

# Iterate over all available apartments
for i in range(0, len(apts.find_all("ea5-unit"))):
    model += [apts.find_all("ea5-unit")[i].find_all('p')[1].get_text().strip()]
    available += [apts.find_all('ea5-unit')[i].find_all('p')[3].get_text().strip().split(" ")[1]]
    price += [apts.find_all("ea5-unit")[i].find_all("span")[0].get_text().split('$')[1]]
    time_period += [apts.find_all("ea5-unit")[i].find_all("span")[1].get_text()]
    area += [apts.find_all("ea5-unit")[i].find_all("span")[2].get_text().split(" ")[0]]
    image += [apts.find_all("ea5-unit")[i].find('img')['src']]
    
    # Handling Missing floor...
    try:
        apts.find_all("ea5-unit")[i].find_all("span")[3].get_text().split(" ")[1]
    except:
        floor += ['NA']
    else: 
        floor += [apts.find_all("ea5-unit")[i].find_all("span")[3].get_text().split(" ")[1]]
    
    # Hanlding multiple amenities...
    tmp = list()
    for j in range(0, len(apts.find_all("ea5-unit")[i].find_all('p', class_= 'amenity'))):
        tmp += [apts.find_all("ea5-unit")[i].find_all('p', class_= 'amenity')[j].get_text().strip()]
    amenity += [tmp]
    
# Create a data frame for return
d = {'model': model, 'price': price, 'available': available, 'time_period': time_period, 
     'area': area, 'floor': floor, 'amenity': amenity, 'image': image}
df = pandas.DataFrame(data=d)
df
# Out:
#              model  price   available time_period  area floor  \
# 0   1 Bed / 1 Bath  2,520  12/21/2020       12 mo   769     4
# 1   1 Bed / 1 Bath  2,530  12/27/2020       12 mo   769     5
# 2   1 Bed / 1 Bath  2,541    1/1/2021       12 mo   769     6
# 3   1 Bed / 1 Bath  2,582   1/29/2021       12 mo   703     5
# 4   1 Bed / 1 Bath  2,582   2/11/2021       12 mo   741     7
# 5   1 Bed / 1 Bath  2,593  12/17/2020       12 mo   712     6
# 6   1 Bed / 1 Bath  2,598  12/17/2020       12 mo   703     4
# 7   1 Bed / 1 Bath  2,608   2/20/2021       12 mo   741     7
# 8   1 Bed / 1 Bath  2,624    1/6/2021       12 mo   741     4
# 9   1 Bed / 1 Bath  2,804   1/11/2021       12 mo   830     4
# 10  1 Bed / 1 Bath  2,959   1/11/2021       12 mo   889     4
# 11  1 Bed / 1 Bath  2,969  12/17/2020       12 mo   889     5
# 12  1 Bed / 1 Bath  2,979   1/23/2021       12 mo   984    NA
# 13  1 Bed / 1 Bath  2,995  12/19/2020       12 mo   889     5
# 14  1 Bed / 1 Bath  3,006  12/22/2020       12 mo   889     6
# 15  1 Bed / 1 Bath  3,041  12/17/2020       12 mo  1032     3
# 16  1 Bed / 1 Bath  3,067  12/21/2020       12 mo   740     7
# 17  1 Bed / 1 Bath  3,082   1/28/2021       12 mo  1032     4
# 18  1 Bed / 1 Bath  3,302  12/17/2020       12 mo   816     7
# 19  2 Bed / 2 Bath  3,643   2/19/2021       12 mo  1031     5
# 20  2 Bed / 2 Bath  3,910  12/19/2020       12 mo  1252     3
# 21  2 Bed / 2 Bath  3,987   2/27/2021       12 mo  1252     6
# 22  2 Bed / 2 Bath  4,241   1/21/2021       12 mo  1253     7
#
#                                               amenity  \
# 0                                         [Renovated]
# 1                                         [Renovated]
# 2                                         [Renovated]
# 3          [Balcony, Renovated, View of Hudson River]
# 4   [Juliet Balcony, Renovated, View of Hudson River]
# 5          [Balcony, Renovated, View of Hudson River]
# 6                                [Balcony, Renovated]
# 7                         [Juliet Balcony, Renovated]
# 8          [Balcony, Renovated, View of Hudson River]
# 9                                [Balcony, Renovated]
# 10  [Balcony, Extra Den Space with Door, Renovated...
# 11  [Balcony, Extra Den Space with Door, Renovated...
# 12  [Extra Den Space with Door, Renovated, View of...
# 13    [Balcony, Extra Den Space with Door, Renovated]
# 14    [Balcony, Extra Den Space with Door, Renovated]
# 15  [Extra Den Space with Door, Renovated, View of...
# 16              [Balcony, Private Terrace, Renovated]
# 17             [Extra Den Space with Door, Renovated]
# 18                [Patio, Private Terrace, Renovated]
# 19         [Balcony, Renovated, View of Hudson River]
# 20                [Granite Kitchen Island, Renovated]
# 21  [Granite Kitchen Island, Renovated, View of NY...
# 22            [Private Terrace, View of Hudson River]
#
#                                                 image
# 0   https://media.equityapartments.com/image/uploa...
# 1   https://media.equityapartments.com/image/uploa...
# 2   https://media.equityapartments.com/image/uploa...
# 3   https://media.equityapartments.com/image/uploa...
# 4   https://media.equityapartments.com/image/uploa...
# 5   https://media.equityapartments.com/image/uploa...
# 6   https://media.equityapartments.com/image/uploa...
# 7   https://media.equityapartments.com/image/uploa...
# 8   https://media.equityapartments.com/image/uploa...
# 9   https://media.equityapartments.com/image/uploa...
# 10  https://media.equityapartments.com/image/uploa...
# 11  https://media.equityapartments.com/image/uploa...
# 12  https://media.equityapartments.com/image/uploa...
# 13  https://media.equityapartments.com/image/uploa...
# 14  https://media.equityapartments.com/image/uploa...
# 15  https://media.equityapartments.com/image/uploa...
# 16  https://media.equityapartments.com/image/uploa...
# 17  https://media.equityapartments.com/image/uploa...
# 18  https://media.equityapartments.com/image/uploa...
# 19  https://media.equityapartments.com/image/uploa...
# 20  https://media.equityapartments.com/image/uploa...
# 21  https://media.equityapartments.com/image/uploa...
# 22  https://media.equityapartments.com/image/uploa...

# %%
df.to_csv('The_Pier_availability.csv')

# %% [markdown]
# ### [Windsor at Liberty House](https://www.windsoratlibertyhouse.com/)

# %%
# Store the URL as a variable
url = 'https://www.windsoratlibertyhouse.com/floorplans'

# Create a headers with user agent string
headers = {'user-agent': 'David Xu Personal Use (cx2rx@virginia.edu)'}

# Get the URL page
r = requests.get(url, headers = headers)

# Check status
print(r)
# Out:
# <Response [200]>

# %%
# Parse the HTML with Beautiful Soup
apts = BeautifulSoup(r.text, 'html.parser')

# Create empty list to store results
name = list()
available = list()
n_bed = list()
n_bath = list()
area = list()
min_rent = list()
max_rent = list()
deposit = list()
description = list()
image = list()

# Iterate over all available apartments
for i in range(0, len(apts.find_all("div", class_="row border-bottom pb-3 mb-3"))):
    
    # If there is a video, add 1 to the index
    if apts.find_all("div", class_="row border-bottom pb-3 mb-3")[i].\
        find_all('span')[0].get_text().strip() == 'Video':
        index = 1
    else:
        index = 0
    
    # If there is no apartment available, there is no rent
    if apts.find_all("div", class_="row border-bottom pb-3 mb-3")[i].\
                  find_all('span')[index + 1].get_text().split(" ")[0] == '0':
        
        min_rent += ['NA']
        max_rent += ['NA']
    
    else:
        # Minimum Rent
        min_rent += [apts.find_all("div", class_="row border-bottom pb-3 mb-3")[i].\
                 find_all('span')[-3].get_text().split(" ")[0][:-2]]
        # Maximum Rent
        max_rent += [apts.find_all("div", class_="row border-bottom pb-3 mb-3")[i].\
                 find_all('span')[-3].get_text().split(" ")[2]]
        
    # Apartment Name
    name += [apts.find_all("div", class_="row border-bottom pb-3 mb-3")[i].\
             find_all('span')[index + 0].get_text().strip()]
    # Number of Available Apartments
    available += [apts.find_all("div", class_="row border-bottom pb-3 mb-3")[i].\
                  find_all('span')[index + 1].get_text().split(" ")[0]]
    # Number of Bedroom 
    n_bed += [apts.find_all("div", class_="row border-bottom pb-3 mb-3")[i].\
              find_all('span')[index + 2].get_text().split(" ")[0]]
    # Number of Bathroom 
    n_bath += [apts.find_all("div", class_="row border-bottom pb-3 mb-3")[i].\
               find_all('span')[index + 4].get_text().split(" ")[0]]
    # Area
    area += [apts.find_all("div", class_="row border-bottom pb-3 mb-3")[i].\
             find_all('span')[index + 6].get_text().split(" ")[0]]
    
    # Deposit
    deposit += [apts.find_all("div", class_="row border-bottom pb-3 mb-3")[i].\
                find_all('span')[-1].get_text()]
    # Description
    description += [apts.find_all("div", class_="row border-bottom pb-3 mb-3")[i].\
                    find_all('p')[0].get_text().strip()]
    # image
    image += [apts.find_all("div", class_="row border-bottom pb-3 mb-3")[i].find_all('img')[0]['data-images']]
    
    
# Create a data frame for return
d = {'Apartment Name': name, 'Number of Available Apartments': available, 'Number of Bedroom': n_bed, 
     'Number of Bathroom': n_bath, 'Area': area, 'Minimum Rent': min_rent, 
     'Maximum Rent': max_rent, 'Deposit': deposit, 'Description': description, 'Image': image}

df = pandas.DataFrame(data=d).sort_values("Number of Available Apartments", ascending = False)
df
# Out:
#           Apartment Name Number of Available Apartments Number of Bedroom  \
# 9                 Bishop                              4                 2
# 1                 Ashton                              3                 1
# 0              Alexander                              3                 1
# 2                 Asbury                              2                 1
# 14     Baldwin Penthouse                              2                 3
# 3             Bainbridge                              1                 1
# 10      Asbury Penthouse                              1                 2
# 11      Ashton Penthouse                              1                 2
# 4                 Andrew                              0                 1
# 5                  Astor                              0                 1
# 6               Abington                              0                 1
# 7                Baldwin                              0                 1
# 8              Avonleigh                              0                 1
# 12             Trecastle                              0                 2
# 13                Beacon                              0                 2
# 15  Bainbridge Penthouse                              0                 3
# 16  Barrington Penthouse                              0                 3
# 17             Cambridge                              0                 3
# 18      Bishop Penthouse                              0                 3
#
#    Number of Bathroom   Area Minimum Rent Maximum Rent Deposit  \
# 9                   2  1,071       $3,490       $4,305  $1,000
# 1                   1    774       $2,350       $2,760  $1,000
# 0                   1    712       $2,240       $2,910  $1,000
# 2                   1    719       $2,380       $2,840  $1,000
# 14                  2  1,228       $4,180       $4,895  $1,000
# 3                   1    932       $2,880       $3,465  $1,000
# 10                  2    956       $3,440       $4,255  $1,000
# 11                  2  1,057       $3,530       $4,130  $1,000
# 4                   1    697           NA           NA  $1,000
# 5                   1    716           NA           NA  $1,000
# 6                   1    750           NA           NA  $1,000
# 7                   1    923           NA           NA  $1,000
# 8                   1    929           NA           NA  $1,000
# 12                2.5  1,237           NA           NA  $1,000
# 13                  2  1,252           NA           NA  $1,000
# 15                  2  1,215           NA           NA  $1,000
# 16                  2  1,241           NA           NA  $1,000
# 17                  2  1,340           NA           NA  $1,000
# 18                  2  1,392           NA           NA  $1,000
#
#                                           Description  \
# 9   Our Bishop apartment homes features 2-bedrooms...
# 1   The Ashton is perfect if you're looking for a ...
# 0   The Alexander is perfect if you're looking for...
# 2   If you are looking for great natural light, th...
# 14  Our Baldwin Penthouse is a luxurious duplex-st...
# 3   Our Bainbridge apartments feature 1-bedroom, 1...
# 10  The Asbury Penthouse is a two floor 2-bedroom,...
# 11  The Ashton Penthouse duplex-styled apartment f...
# 4   The Andrew is our coziest apartment available ...
# 5   Perfect one-bedroom for the resident looking f...
# 6   The Abington features a large kitchen with ple...
# 7   Our Baldwin apartment features 1-bedroom, 1-ba...
# 8   This unique 1-bedroom, 2-bath floor plan featu...
# 12  The Trecastle townhome styled floor plan is th...
# 13  The Beacon is one of the most spacious 2-bedro...
# 15                 Beautiful three bedroom penthouse!
# 16  Our Barrington Penthouse is a luxurious duplex...
# 17  Our 3-bedroom, 2-bathroom Cambridge apartment ...
# 18  The Bishop Penthouse, a 2-bedroom/2-bath duple...
#
#                                                 Image
# 9   https://res.cloudinary.com/yardi/image/upload/...
# 1   https://res.cloudinary.com/yardi/image/upload/...
# 0   https://res.cloudinary.com/yardi/image/upload/...
# 2   https://res.cloudinary.com/yardi/image/upload/...
# 14  https://res.cloudinary.com/yardi/image/upload/...
# 3   https://res.cloudinary.com/yardi/image/upload/...
# 10  https://res.cloudinary.com/yardi/image/upload/...
# 11  https://res.cloudinary.com/yardi/image/upload/...
# 4   https://res.cloudinary.com/yardi/image/upload/...
# 5   https://res.cloudinary.com/yardi/image/upload/...
# 6   https://res.cloudinary.com/yardi/image/upload/...
# 7   https://res.cloudinary.com/yardi/image/upload/...
# 8   https://res.cloudinary.com/yardi/image/upload/...
# 12  https://res.cloudinary.com/yardi/image/upload/...
# 13  https://res.cloudinary.com/yardi/image/upload/...
# 15  https://res.cloudinary.com/yardi/image/upload/...
# 16  https://res.cloudinary.com/yardi/image/upload/...
# 17  https://res.cloudinary.com/yardi/image/upload/...
# 18  https://res.cloudinary.com/yardi/image/upload/...

# %%
df.to_csv('Windsor_at_Liberty_House_availability.csv')

# %% [markdown]
# ### [Vine](https://vinehoboken.com/)

# %%
# Store the URL as a variable
url = 'https://vinehoboken.com/floorplans/'

# Create a headers with user agent string
headers = {'user-agent': 'David Xu Personal Use (cx2rx@virginia.edu)'}

# Get the URL page
r = requests.get(url, headers = headers)

# Check status
print(r)
# Out:
# <Response [200]>

# %%
# Parse the HTML with Beautiful Soup
apts = BeautifulSoup(r.text, 'html.parser')

# %%
# Create empty list to store results
name = list()
amenity = list()
n_bed = list()
n_bath = list()
area = list()
term = list()
price = list()
image = list()

for i in range(0, len(apts.find_all('div', class_='fpm fpm--enhanced')[0].find_all("li"))):

    # New page:
    new_url = apts.find_all('div', class_='fpm fpm--enhanced')[0].find_all("li")[i].find_all('a')[0]['href']

    # Get the URL page
    new_r = requests.get(new_url, headers = headers)
    new_apts = BeautifulSoup(new_r.text, 'html.parser')

    # Name
    name += [new_apts.find_all('div', class_='fpm-unit-details__container')[0].\
        find_all('p')[0].get_text().strip()]
    # Number of Bedroom
    n_bed += [new_apts.find_all('div', class_='fpm-unit-details__container')[0].\
        find_all('p', class_= "fpm-unit-details__info-content")[0].\
        get_text().strip().split(' ')[0]]
    # Number of Bathroom
    n_bath += [new_apts.find_all('div', class_='fpm-unit-details__container')[0].\
        find_all('p', class_= "fpm-unit-details__info-content")[1].\
        get_text().strip().split(' ')[0]]
    # Amentiy
    amenity += [new_apts.find_all('div', class_='fpm-unit-details__container')[0].\
        find_all('p')[3].get_text().strip()]
    # Area
    area += [new_apts.find_all('div', class_='fpm-unit-details__container')[0].\
        find_all('p', class_= "fpm-unit-details__info-content")[-1].\
        get_text().strip().split(' ')[0]]
    # Price
    price += [new_apts.find_all('p', class_='fpm-unit-details__details-info-content')[0].\
        get_text().strip().split(':')[1].strip()]
    # Lease Term
    term += [new_apts.find_all('div', class_='fpm-unit-details__container')[0].
        find_all('p', class_="fpm-unit-details__lease-term-no-terms")[0].get_text()]

    # Image
    image += [new_apts.find_all('div', class_='fpm-unit-details__container')[0].\
        find_all('img')[1]['src']]
    
    
# Create a data frame for return
d = {'Apartment Name': name, 'Number of Bedroom': n_bed, 
     'Number of Bathroom': n_bath, 'Area': area, 'Price': price, 
     'Amenity': amenity, 'Term': term, 'Image': image}

df = pandas.DataFrame(data=d)
df
# Out:
#     Apartment Name Number of Bedroom Number of Bathroom  Area       Price  \
# 0    A-Line Floor4                 3                  2  1319  Contact Us
# 1   B Line Floor 4                 1                  1   Sq.  Contact Us
# 2     Residence 13                 1                  1   850  Contact Us
# 3     Residence 14                 1                  1  1495  Contact Us
# 4   F Line Floor 3                 2                  2   Sq.  Contact Us
# ..             ...               ...                ...   ...         ...
# 58    Residence 12                 1                  1   917  Contact Us
# 59    Residence 12                 1                  1   917  Contact Us
# 60    Residence 13                 1                  1   850  Contact Us
# 61    Residence 14                 1                  1   798  Contact Us
# 62    Residence 14                 1                  1  1495  Contact Us
#
#             Amenity                                               Term  \
# 0          +Terrace  There are currently no lease terms set for thi...
# 1          +Terrace  There are currently no lease terms set for thi...
# 2          +Terrace  There are currently no lease terms set for thi...
# 3    +Den & Terrace  There are currently no lease terms set for thi...
# 4          +Terrace  There are currently no lease terms set for thi...
# ..              ...                                                ...
# 58             +Den  There are currently no lease terms set for thi...
# 59            + Den  There are currently no lease terms set for thi...
# 60      850 Sq. Ft.  There are currently no lease terms set for thi...
# 61      798 Sq. Ft.  There are currently no lease terms set for thi...
# 62  + Den + Terrace  There are currently no lease terms set for thi...
#
#                                                 Image
# 0   https://vinehoboken.com/assets/images/floorpla...
# 1   https://vinehoboken.com/assets/images/floorpla...
# 2   https://vinehoboken.com/assets/images/floorpla...
# 3   https://vinehoboken.com/assets/images/floorpla...
# 4   https://vinehoboken.com/assets/images/floorpla...
# ..                                                ...
# 58  https://vinehoboken.com/assets/images/floorpla...
# 59    https://vinehoboken.com/assets/images/12-11.svg
# 60  https://vinehoboken.com/assets/images/floorpla...
# 61  https://vinehoboken.com/assets/images/floorpla...
# 62     https://vinehoboken.com/assets/images/14-1.svg
#
# [63 rows x 8 columns]

# %%
df.to_csv('Vine_availability.csv')
