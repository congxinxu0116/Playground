# %% [markdown]
# # TED Talk Webscraper
#
# - Author: Congxin (David) Xu,
# - Email: congxin.xu@richmond.edu
# - Date: 2020-12-24

# %%
import selenium
from selenium.webdriver.chrome.options import Options
import pandas
import requests
from bs4 import BeautifulSoup
from time import sleep

# webdriver options
options = Options()
options.headless = False
options.add_argument("--window-size=1920,1200")


url = 'https://www.youtube.com/c/TED/videos'
driver = selenium.webdriver.Chrome(options=options)
driver.get(url)
list_of_videos = BeautifulSoup(driver.page_source, 'html.parser')

# %%
video_url = list()

for i in range(0, len(list_of_videos.find_all('ytd-grid-video-renderer'))):
    video_url += ["https://www.youtube.com" + \
                  list_of_videos.find_all('ytd-grid-video-renderer')[i].find_all('a')[0]['href']]

# %%
video_url
# Out:
# ['https://www.youtube.com/watch?v=klXVQsbhFsE',
#  'https://www.youtube.com/watch?v=dKob6b8QzkU',
#  'https://www.youtube.com/watch?v=TST0CsV8LHI',
#  'https://www.youtube.com/watch?v=2hCUq6ScWME',
#  'https://www.youtube.com/watch?v=BcOey28XXIw',
#  'https://www.youtube.com/watch?v=IeajljTsrOc',
#  'https://www.youtube.com/watch?v=VnR5H7YSk1k',
#  'https://www.youtube.com/watch?v=cFwbA6Zi7w4',
#  'https://www.youtube.com/watch?v=3SQUXasUQOA',
#  'https://www.youtube.com/watch?v=MqtffzWvzOQ',
#  'https://www.youtube.com/watch?v=dZtnOnqcDN4',
#  'https://www.youtube.com/watch?v=oDtolKlL7jE',
#  'https://www.youtube.com/watch?v=lWaZzww6Tlc',
#  'https://www.youtube.com/watch?v=vR4RGzUpOQw',
#  'https://www.youtube.com/watch?v=OPfVCUGxyHs',
#  'https://www.youtube.com/watch?v=3PmqknYmY9Q',
#  'https://www.youtube.com/watch?v=6UiU99_tE7I',
#  'https://www.youtube.com/watch?v=NMVgg6zuiB0',
#  'https://www.youtube.com/watch?v=VU44eEKtcmQ',
#  'https://www.youtube.com/watch?v=k3clwllhdlg',
#  'https://www.youtube.com/watch?v=vMQlj9TZQfE',
#  'https://www.youtube.com/watch?v=xiwIvp7aKRk',
#  'https://www.youtube.com/watch?v=EKBpF2bzpNs',
#  'https://www.youtube.com/watch?v=IcaDZK1Njb0',
#  'https://www.youtube.com/watch?v=1Mwki3RIybU',
#  'https://www.youtube.com/watch?v=N4tP-OCG6jU',
#  'https://www.youtube.com/watch?v=d4Cy16uOdLM',
#  'https://www.youtube.com/watch?v=5LRhKegPCRY',
#  'https://www.youtube.com/watch?v=7ErKuXByRto',
#  'https://www.youtube.com/watch?v=SHY4KH4PK7Y']

# %%
title = list()
speaker = list()
release_date = list()
likes = list()
dislikes = list()
views = list()

for link in video_url:
    # Create driver
    driver.get(link)
    sleep(1)
    
    # Get page_source
    video = BeautifulSoup(driver.page_source, 'html.parser')
    
    # Title
    title += [video.find_all(class_ = 'style-scope ytd-video-primary-info-renderer')[0].\
        find_all('yt-formatted-string')[1].get_text().split("|")[0].strip()]
    # Speaker
    speaker += [video.find_all(class_ = 'style-scope ytd-video-primary-info-renderer')[0].\
        find_all('yt-formatted-string')[1].get_text().split("|")[1].strip()]
    # Release Date
    release_date += [video.find_all(class_ = 'style-scope ytd-video-primary-info-renderer')[0].\
        find_all('yt-formatted-string')[2].get_text()]
    # Likes
    likes += [video.find_all(class_ = 'style-scope ytd-video-primary-info-renderer')[0].\
        find_all('yt-formatted-string')[3]['aria-label'].split(" ")[0]]
    # Dislikes
    dislikes += [video.find_all(class_ = 'style-scope ytd-video-primary-info-renderer')[0].\
        find_all('yt-formatted-string')[4]['aria-label'].split(" ")[0]]
    # Views
    views += [video.find_all(class_ = 'style-scope ytd-video-primary-info-renderer')[0].\
        find_all('span')[0].get_text().split(" ")[0]]
    
    
# Create a data frame for return
d = {'Title': title, 'Speaker': speaker, 'Release Date': release_date, 'Likes': likes, 
     'Dislikes': dislikes, 'Views': views, 'URL': video_url}
df = pandas.DataFrame(data=d)
df
# Out:
#                                                 Title  \
# 0   How to foster true diversity and inclusion at ...
# 1     Why monkeys (and humans) are wired for fairness
# 2               A stellar history of modern astronomy
# 3    An aerialist on listening to your body's signals
# 4         A playful exploration of gender performance
# 5   Could we treat spinal cord injuries with aspar...
# 6   How quinoa can help combat hunger and malnutri...
# 7      A magical mantra for nurturing a blissful life
# 8                   What it takes to crush a pandemic
# 9                   The mood-boosting power of crying
# 10  Fossil fuel companies know how to stop global ...
# 11  To future generations of women, you are the ro...
# 12  How the new generation of Latinx voters could ...
# 13  How COVID-19 human challenge trials work -- an...
# 14     The city planting a million trees in two years
# 15            How to come out at work, about anything
# 16  How we can use the hiring process to bring out...
# 17  How reverse mentorship can help create better ...
# 18    How working couples can best support each other
# 19     I stepped out of grief -- by dancing with fire
# 20  Theranos, whistleblowing and speaking truth to...
# 21                               If trees could speak
# 22  How to be fearless in the face of authoritaria...
# 23                    What crows teach us about death
# 24    How to foster productive and responsible debate
# 25  Kids are speaking up for the environment. Let'...
# 26  How to decarbonize the grid and electrify ever...
# 27  The power of venom -- and how it could one day...
# 28  Climate change is becoming a problem you can t...
# 29                                           "Shadow"
#
#                           Speaker  Release Date   Likes Dislikes    Views  \
# 0              Rosalind G. Brewer  Dec 22, 2020     591      916   30,883
# 1                   Sarah Brosnan  Dec 21, 2020   1,779       84   41,959
# 2                  Emily Levesque  Dec 18, 2020   1,640       45   57,850
# 3                    Adie Delaney  Dec 17, 2020   1,571       38   39,720
# 4                Jo Michael Rezes  Dec 15, 2020     371      108   20,825
# 5                  Andrew Pelling  Dec 11, 2020   2,028       48   51,128
# 6              Cedric Habiyaremye  Dec 10, 2020   1,880       24   36,229
# 7                JayaShri Maathaa   Dec 9, 2020   1,432       94   36,590
# 8                 Johanna Benesty   Dec 8, 2020   1,173      142   40,173
# 9                   Kathy Mendias   Dec 7, 2020   1,223      116   37,690
# 10                    Myles Allen   Dec 4, 2020   2,493      174   61,391
# 11                 Gloria Steinem   Dec 3, 2020   1,336      377   39,126
# 12             María Teresa Kumar   Dec 2, 2020     116       83    8,638
# 13                    Sophie Rose   Dec 1, 2020   1,022      154   38,695
