# %%
import pandas
import numpy

# %%
path = 'C:\\Users\\DaDa\\Documents\\GitHub\\Playground\\'
data = pandas.read_excel( 'C:\\Users\\DaDa\\Documents\\GitHub\\Playground\\Therapeutics Distribution.xlsx')
data.head()
# Out:
#         Date  Year     Month  Day REGENCOV BAMETE Evusheld Sotrovimab  \
# 0 2022-02-28  2022  February   28       0​      0  49,992​     46,986
# 1 2022-02-21  2022  February   21       0​      0  49,992​    52,194​
# 2 2022-02-14  2022  February   14        0      0   49,992     52,248
# 3 2022-02-07  2022  February    7       0​     0​  49,264​     52,248
# 4 2022-01-31  2022   January   31        0      0   74,960     52,104
#
#   Bebtelovimab  Paxlovid Molnupiravir
# 0       51,990         0            0
# 1      49,000​  148,980​     349,776​
# 2       48,745         0            0
# 3            0   99,940​      399,840
# 4            0         0            0
