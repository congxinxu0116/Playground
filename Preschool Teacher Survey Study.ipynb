# %% [markdown]
# # Preschool Teacher Survey Study
#
# - Author: Congxin (David) Xu
# - Date: May 25, 2021

# %%
import pandas
import numpy
import matplotlib

# %%
parent_data = pandas.read_excel('C:\\David\\Mom and Dad\\调研最终数据422\\早教教师需求调查（家长问卷）422.xlsx')
parent_data.head()
# Out:
#    序号              提交答卷时间  所用时间    来源  来源详情                   来自IP  \
# 0   1  2020/4/15 19:47:12   92秒    微信   NaN   112.28.172.92(安徽-合肥)
# 1   2  2020/4/15 20:03:28  127秒  手机提交  直接访问     112.32.15.8(安徽-合肥)
# 2   3  2020/4/15 20:04:54  101秒    微信   NaN  114.87.166.253(上海-上海)
# 3   4  2020/4/15 20:11:59   61秒    微信   NaN    36.5.159.234(安徽-合肥)
# 4   5  2020/4/15 20:18:19  109秒    微信   NaN   112.32.14.225(安徽-合肥)
#
#     1.您所在的地区是？  2.您是孩子的？  3 (早教中心)  3 (幼儿园（早教班/托班）)  ...  8 (文化知识)  8 (专业理论)  \
# 0   安徽-合肥市-蜀山区         2         1                0  ...         0         1
# 1   安徽-合肥市-庐阳区         2         0                1  ...         1         1
# 2  上海-上海市-浦东新区         2         1                1  ...         0         1
# 3   安徽-合肥市-蜀山区         2         1                0  ...         1         1
# 4   安徽-合肥市-蜀山区         2         1                0  ...         0         1
#
#    8 (保育保健能力)  8 (亲子活动组织能力)  8 (家庭教育指导能力)  8 (音乐表现能力)  8 (沟通、人际交往能力)  \
# ...

# %%
parent_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 576 entries, 0 to 575
# Data columns (total 38 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   序号                   576 non-null    int64
#  1   提交答卷时间               576 non-null    object
#  2   所用时间                 576 non-null    object
#  3   来源                   576 non-null    object
#  4   来源详情                 205 non-null    object
#  5   来自IP                 576 non-null    object
#  6   1.您所在的地区是？           576 non-null    object
#  7   2.您是孩子的？             576 non-null    int64
#  8   3 (早教中心)             576 non-null    int64
#  9   3 (幼儿园（早教班/托班）)      576 non-null    int64
#  10  3 (托育机构)             576 non-null    int64
#  11  3 (社区早教服务中心)         576 non-null    int64
#  12  3 (其他)               576 non-null    int64
#  13  4. 您的文化程度是？          576 non-null    int64
#  14  5. 您是否知道您孩子早教教师的学历?  576 non-null    int64
# ...
