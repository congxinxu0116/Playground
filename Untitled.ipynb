# %% [markdown]
# # DMV Web Scraper

# %%
import requests
page = requests.get("https://vadmvappointments.as.me/schedule.php?calendarID=3886205")
page
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://app.acuityscheduling.com/schedule.php?owner=19444409" rel="canonical"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <title>
#    Schedule Appointment with Virginia Department of Motor Vehicles
#   </title>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=2.0" name="viewport"/>
#   <meta content="same-origin" name="referrer"/>
#   <meta content="date=no" name="format-detection"/>
#   <meta content="Schedule your appointment online  Virginia Department of Motor Vehicles" name="description">
#    <meta content="465400520261032" property="fb:app_id">
#     <meta content="website" property="og:type">
#      <meta content="https://app.acuityscheduling.com/schedule.php?owner=19444409&amp;calendarID=3886205" property="og:url"/>
#      <meta content="Virginia Department of Motor Vehicles" property="og:title"/>
# ...

# %%
soup.find_all(class_= "select select-type many-types closed")
# Out:
# []
